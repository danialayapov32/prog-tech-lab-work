# %%
import numpy as np


x_idx = header_cols.index(x_name)
y_idx = header_cols.index(y_name)


data_array = np.genfromtxt('plot_data.csv', delimiter=',', skip_header=1, usecols=(x_idx, y_idx))

print("Данные загружены в массив NumPy:")
print(data_array)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
# ----> 4 x_idx = header_cols.index(x_name)
#       5 y_idx = header_cols.index(y_name)
#       8 data_array = np.genfromtxt('plot_data.csv', delimiter=',', skip_header=1, usecols=(x_idx, y_idx))
#
# NameError: name 'header_cols' is not defined
